# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from feature_engine.creation import CyclicalFeatures
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 12
#      10 from sklearn.ensemble import RandomForestClassifier
#      11 from sklearn.datasets import load_iris
# ---> 12 from feature_engine.creation import CyclicalFeatures
#
# ModuleNotFoundError: No module named 'feature_engine.creation'

# %%
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Removing data

# %% [markdown]
# ### Removing outliers

# %%
# Removing invalid data
print(train.size)
train = train[train["Y"] != 90]
print(train.size)
# Out:
# 7902441
# 7901838

# %% [markdown]
# ### Removing irrelevant columns

# %%
test = test.drop(['Id', 'Address'], axis=1)

# %% [markdown]
# ## Clean date feature

# %% [markdown]
# ### Convert date item to datetime object

# %%
test['Dates'] = pd.to_datetime(test["Dates"])
test
# Out:
#                      Dates  DayOfWeek PdDistrict           X          Y
# 0      2015-05-10 23:59:00     Sunday    BAYVIEW -122.399588  37.735051
# 1      2015-05-10 23:51:00     Sunday    BAYVIEW -122.391523  37.732432
# 2      2015-05-10 23:50:00     Sunday   NORTHERN -122.426002  37.792212
# 3      2015-05-10 23:45:00     Sunday  INGLESIDE -122.437394  37.721412
# 4      2015-05-10 23:45:00     Sunday  INGLESIDE -122.437394  37.721412
# ...                    ...        ...        ...         ...        ...
# 884257 2003-01-01 00:01:00  Wednesday    MISSION -122.408983  37.751987
# 884258 2003-01-01 00:01:00  Wednesday   NORTHERN -122.425342  37.792681
# 884259 2003-01-01 00:01:00  Wednesday  INGLESIDE -122.445418  37.712075
# 884260 2003-01-01 00:01:00  Wednesday    BAYVIEW -122.387394  37.739479
# 884261 2003-01-01 00:01:00  Wednesday    TARAVAL -122.489714  37.733950
#
# [884262 rows x 5 columns]

# %% [markdown]
# ### Break up datetime object into each of its components

# %%
test['Year'] = test['Dates'].dt.year
test['Month'] = test['Dates'].dt.month
test['Day'] = test['Dates'].dt.day
test['Hour'] = test['Dates'].dt.hour
test['Minute'] = test['Dates'].dt.minute
test['Second'] = test['Dates'].dt.second
test
# Out:
#                      Dates  DayOfWeek PdDistrict           X          Y  Year  \
# 0      2015-05-10 23:59:00     Sunday    BAYVIEW -122.399588  37.735051  2015
# 1      2015-05-10 23:51:00     Sunday    BAYVIEW -122.391523  37.732432  2015
# 2      2015-05-10 23:50:00     Sunday   NORTHERN -122.426002  37.792212  2015
# 3      2015-05-10 23:45:00     Sunday  INGLESIDE -122.437394  37.721412  2015
# 4      2015-05-10 23:45:00     Sunday  INGLESIDE -122.437394  37.721412  2015
# ...                    ...        ...        ...         ...        ...   ...
# 884257 2003-01-01 00:01:00  Wednesday    MISSION -122.408983  37.751987  2003
# 884258 2003-01-01 00:01:00  Wednesday   NORTHERN -122.425342  37.792681  2003
# 884259 2003-01-01 00:01:00  Wednesday  INGLESIDE -122.445418  37.712075  2003
# 884260 2003-01-01 00:01:00  Wednesday    BAYVIEW -122.387394  37.739479  2003
# 884261 2003-01-01 00:01:00  Wednesday    TARAVAL -122.489714  37.733950  2003
#
# ...

# %% [markdown]
# ### Convert data to cyclical columns where need be Source: https://feature-engine.trainindata.com/en/latest/user_guide/creation/CyclicalFeatures.html

# %% [markdown]
# ##

# %% [markdown]
# ### Create target variable

# %%
target = train["Category"]

# %% [markdown]
# ### Remove variables only provided in test dataset

# %%
features = train.drop(columns=["Category", "Descript", "Resolution"])

# %%
test_no_id = test.drop(columns=["Id"])

# %%
classifier = RandomForestClassifier(n_estimators=10, random_state=42)
classifier.fit(features, target)
y_pred = classifier.predict(test_no_id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20416\3374972945.py in ?()
#       1 classifier = RandomForestClassifier(n_estimators=10, random_state=42)
# ----> 2 classifier.fit(features, target)
#       3 y_pred = classifier.predict(test_no_id)
#
# c:\Users\ceddy\anaconda3\envs\SanFran\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\ceddy\anaconda3\envs\SanFran\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     355         # Validate or convert input data
#     356         if issparse(y):
# ...
